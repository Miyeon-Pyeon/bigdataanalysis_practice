# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/bigdataanalysis_practice/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0_3%EC%9C%A0%ED%98%95_%EC%97%B0%EC%8A%B5(5%2C4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 5회 기출

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e5_p3_1.csv')
df.head()
# Out:
#        ID  height
# 0  user_1  164.57
# 1  user_2  174.99
# 2  user_3  171.41
# 3  user_4  162.47
# 4  user_5  167.11

# %%
# 1
# 55명 학생들의 키에 대한 표본 평균을 구하여라(반올림하여 소숫점 3째자리까지

ans = df['height'].mean()
print(round(ans,3))
# Out:
# 169.937

# %%
# 2
# t분포 양쪽 꼬리에서의 t 값을 구하여라 (반올림하여 소수4째자리까지)

import numpy as np
from scipy.stats import t

std = np.std(df.height, ddof=1)
n = len(df.height)

confidence_level = 0.95
ddof = n - 1

t_value = round(t.ppf((1 + confidence_level) / 2, ddof), 4)
print(t_value)
# Out:
# 2.0049

# %%
# 3
# 95% 신뢰구간을 구하여라(print(lower,upper) 방식으로 출력, 각각의 값은 소숫점 이하 3째자리까지)

lower = round(ans - t_value * std / np.sqrt(n), 3)
upper = round(ans + t_value * std / np.sqrt(n), 3)

print(lower)
print(upper)
# Out:
# 168.321
# 171.553

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e5_p3_2.csv')
df.head()
# Out:
#   ID      value
# 0  A  84.179434
# 1  A  93.971003
# 2  A  62.140957
# 3  A  72.911723
# 4  A  79.252747

# %%
# 4
# 3 그룹의 데이터에 대해 크루스칼-왈리스 검정을 사용하여 검정 통계량을 반올림하여 소숫점 이하 3자리까지 구하여라

from scipy.stats import kruskal

a = df[df.ID == 'A'].value.values
b = df[df.ID == 'B'].value.values
c = df[df.ID == 'C'].value.values

s, p = kruskal(a,b,c)

print(round(s, 3))
# Out:
# 6.521

# %%
# 5
# 3 그룹의 데이터에 대해 크루스칼-왈리스 검정을 사용하여 p-value를 반올림하여 소숫점 이하 3자리까지 구하여라. 귀무가설과 대립가설중 0.05 유의수준에서 유의한 가설을  출력하라

print(round(p, 3))

# 0.05보다 작으므로 기각, 따라서 대립가설이 유의
# Out:
# 0.038

# %% [markdown]
# ## 4회 기출

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e4_p3_1_.csv')
df.head()
# Out:
#          학번     학과 성별
# 0  DFSKJK_1   경영학과  여
# 1  DFSKJK_2   사회학과  여
# 2  DFSKJK_3  기계공학과  여
# 3  DFSKJK_4   경제학과  남
# 4  DFSKJK_5  기계공학과  여

# %%
# 1
# 학과 평균 인원에 대한 값을 소숫점 이하 3자리까지 구하여라

ans = (df.groupby('학과').size()).mean()
print(round(ans, 3))
# Out:
# 170.333

# %%
# 2
# 카이제곱검정 독립성 검정 통계량을 소숫점 이하 3자리까지 구하여라

from scipy.stats import chi2_contingency

table = pd.crosstab(df['학과'], df['성별'])

s, p, _, _ = chi2_contingency(table)

print(round(s, 3))
# Out:
# 5.646

# %%
# 3
# 카이제곱검정 독립성 검정의 pvalue를 소숫점 이하 3자리까지 구하여라. 유의수준 0.05하에서 귀무가설과 대립가설중 유의한 것을 출력하라

print(round(p, 3))
# 0.05보다 크므로 채택, 따라서 귀무가설이 더 적합
# Out:
# 0.342

# %%
# 어느 학교에서 수학 시험을 본 학생 100명 중 60명이 60점 이상을 받았다. 이 학교의 수학 시험의 평균 점수가 50점 이상인지 95%의 신뢰 수준에서 검정하려한다.

# %%
# 4

n = 100
p_hat = 0.6
p =0.5
alpha = 0.05

z = (p_hat -p) / np.sqrt(p*(1-p) / n)
print(round(z, 3))
# Out:
# 2.0

# %%
# 5
# pvalue를 소숫점 이하 3자리까지 구하고 귀무가설과 대립가설중 유의한 것을 출력하라

from scipy.stats import norm
p_value = 1 - norm.cdf(z)
print(round(p_value, 3))

# 0.05보다 작으므로 기각, 따라서 대립가설이 유의
# Out:
# 0.023
