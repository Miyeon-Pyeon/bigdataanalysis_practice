# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/bigdataanalysis_practice/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0_%EC%9E%91%EC%97%851%EC%9C%A0%ED%98%95(%EC%84%9C%EC%9A%B8%EC%8B%9C_%EB%94%B0%EB%A6%89%EC%9D%B4_%EC%9D%B4%EC%9A%A9%EC%A0%95%EB%B3%B4_%EB%8D%B0%EC%9D%B4%ED%84%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/bicycle/seoul_bi.csv')
df.head()
# Out:
#          대여일자  대여시간  대여소번호 대여구분코드 성별 연령대코드  이용건수    운동량   탄소량     이동거리  사용시간
# 0  2021-06-01     0   3541    정기권  F  ~10대     1   0.00  0.00     0.00     8
# 1  2021-06-01     0    765    정기권  F  ~10대     1  27.21  0.35  1526.81    19
# 2  2021-06-01     0   2637    정기권  F  ~10대     1  41.40  0.37  1608.56    18
# 3  2021-06-01     0   2919    정기권  F  ~10대     1   0.00  0.00     0.00    75
# 4  2021-06-01     0    549    정기권  F  ~10대     1  13.04  0.17   731.55     6

# %%
df = df.rename(columns={'대여일자': 'day', '대여시간': 'time', '대여소번호': 'num', '대여구분코드':'code', '성별':'sex', '연령대코드':'range', '이용건수':'frequency', '운동량':'momentum', '탄소량':'carbon', '이동거리':'km', '사용시간':'hour'})

# %%
df.head()
# Out:
#           day  time   num code sex range  frequency momentum carbon       km  \
# 0  2021-06-01     0  3541  정기권   F  ~10대          1     0.00   0.00     0.00
# 1  2021-06-01     0   765  정기권   F  ~10대          1    27.21   0.35  1526.81
# 2  2021-06-01     0  2637  정기권   F  ~10대          1    41.40   0.37  1608.56
# 3  2021-06-01     0  2919  정기권   F  ~10대          1     0.00   0.00     0.00
# 4  2021-06-01     0   549  정기권   F  ~10대          1    13.04   0.17   731.55
#
#    hour
# 0     8
# 1    19
# 2    18
# 3    75
# 4     6

# %%
#31
# 대여일자별 데이터 수를 데이터프레임으로 출력하고 가장 많은 데이터가 있는 날짜를 출력

result = df['대여일자'].value_counts().sort_index().to_frame()
answer = result[result.대여일자  == result.대여일자.max()].index[0]

display(result)
print(answer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-9e6e3d2fc8f3> in <cell line: 5>()
#       3
#       4 result = df['대여일자'].value_counts().sort_index().to_frame()
# ----> 5 answer = result[result.대여일자  == result.대여일자.max()].index[0]
#       6
#       7 display(result)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute '대여일자'

# %%
result.count()
# Out:
# count    14
# dtype: int64

# %%
#32
# 각 일자의 요일을 표기하고 (‘Monday’ ~’Sunday’) ‘day_name’컬럼을 추가하고 이를 이용하여 각 요일별 이용 횟수의 총합을 데이터 프레임으로  출력하라

df['대여일자'] = pd.to_datetime(df['대여일자'])
df['day_name']  = df['대여일자'].dt.day_name()

result =  df.day_name.value_counts().to_frame()
print(result)
# Out:
#             count
# day_name
# Wednesday  110607
# Friday     108877
# Monday     107568
# Tuesday    103704
# Saturday   101299
# Sunday      90918
# Thursday    55977

# %%
#33
# 각 요일별 가장 많이 이용한 대여소의 이용횟수와 대여소 번호를 데이터 프레임으로 출력하라

result = df.groupby(['day_name','대여소번호']).size().to_frame('size').sort_values(['day_name','size'],ascending=False).reset_index()
Ans = result.drop_duplicates('day_name', keep='first').reset_index(drop=True)
display(Ans)
# Out:
#     day_name  대여소번호  size
# 0  Wednesday    502   282
# 1    Tuesday    502   267
# 2   Thursday   2715   137
# 3     Sunday    502   372
# 4   Saturday    502   378
# 5     Monday    502   242
# 6     Friday    502   277

# %%
#34
# 나이대별 대여구분 코드의 (일일권/전체횟수) 비율을 구한 후 가장 높은 비율을 가지는 나이대를 확인하라. 일일권의 경우 일일권 과 일일권(비회원)을 모두 포함하라

daily = df[df.대여구분코드.isin(['일일권','일일권(비회원)'])].연령대코드.value_counts().sort_index()
total = df.연령대코드.value_counts().sort_index()

ratio = (daily/total).sort_values(ascending=False)
print(ratio)
print('가장 높은 비율 나이대:', ratio.index[0])
# Out:
# 연령대코드
# ~10대    0.312525
# 20대     0.239913
# 30대     0.166702
# 40대     0.110585
# 50대     0.065414
# 70대~    0.048962
# 60대     0.042462
# Name: count, dtype: float64
# 가장 높은 비율 나이대: ~10대

# %%
#35
# 연령대별 평균 이동거리

Ans = df.groupby('연령대코드').이동거리.mean().to_frame()
print(Ans)

# Ans = df[['연령대코드','이동거리']].groupby(['연령대코드']).mean()
# print(Ans)
# Out:
#               이동거리
# 연령대코드
# 20대    3211.890552
# 30대    3341.443859
# 40대    3514.857416
# 50대    3593.668100
# 60대    3538.145737
# 70대~   3085.039641
# ~10대   2634.426279

# %%
#36
# 연령대가 20대, 이동거리 값이 추출한 데이터의 이동거리값의 평균 이상인 데이터 추출. 최종 추출한 데이터를 대여일자, 대여소 번호 순서로 내림차순 정렬 후 1행부터 200행까지 탄소량의 평균을 소숫점 3째 자리까지

# 연령대코드와 이동거리 조건을 결합한 후 상위 200개 선택
age = df['연령대코드'] == '20대'
km = df['이동거리'] >= df['이동거리'].mean()

dff = df[age & km].sort_values(['대여일자','대여소번호'], ascending = False).reset_index(drop=True)
two = dff.head(200)

two['탄소량'] =two['탄소량'].astype('float')
two_mean = two['탄소량'].sum()/len(two)
result = round(two_mean, 3)
print(result)

# 연령대코드로 필터링 후 이동거리 조건을 적용하여 다시 필터링 후 상위 200개 선택
# tw = df[df.연령대코드 =='20대'].reset_index(drop=True)
# tw_mean = tw[tw.이동거리 >= tw.이동거리.mean()].reset_index(drop=True)
# tw_mean['탄소량'] =tw_mean['탄소량'].astype('float')
# target =tw_mean.sort_values(['대여일자','대여소번호'], ascending=False).reset_index(drop=True).iloc[:200].탄소량
# result = round(target.sum()/len(target),3)
# print(result)
# Out:
# 1.643
# <ipython-input-40-ada1a828deb1>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   two['탄소량'] =two['탄소량'].astype('float')

# %%
#37
# 6월 7일의 10대 이용건수 중앙값

Ans = df[(df.대여일자 == '2021-06-07') & (df.연령대코드 == '~10대')].이용건수.median()
print(Ans)
# Out:
# 1.0

# %%
#38
# 평일 출근 시간대의 대여소별 이용횟수를 구하고 대여시간별 이용횟수의 상위 3개 대여소와 이용횟수 출력

day = df[df.day_name.isin(['Monday','Tuesday','Wednesday','Thursday','Friday'])]
time = df['대여시간'].isin([6,7,8])
