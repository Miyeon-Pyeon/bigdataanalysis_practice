# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/bigdataanalysis_practice/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0_%EC%A0%84%EC%B2%98%EB%A6%AC_Grouping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 03_Grouping

# %%
import pandas as pd

# %%
#44

df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/AB_NYC_2019.csv')

Ans =df.head(5)

Ans
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#45

# Ans = df.groupby('hostname').size()

Ans = df.host_name.value_counts().sort_index()
Ans.head()
# Out:
# host_name
# 'Cil                        1
# (Ari) HENRY LEE             1
# (Email hidden by Airbnb)    6
# (Mary) Haiy                 1
# -TheQueensCornerLot         1
# Name: count, dtype: int64

# %%
#46
#데이터의 각 host_name의 빈도수를 구하고 빈도수 기준 내림차순 정렬한 데이터 프레임을 만들어라. 빈도수 컬럼은 counts로 명명하라

#Ans = df.groupby('host_name').size().to_frame().rename(columns={0:'counts'}).sort_values('counts', ascending=False)
Ans = df['host_name'].value_counts().to_frame('counts').sort_values('counts', ascending=False)
Ans.head()
# Out:
#               counts
# host_name
# Michael          417
# David            403
# Sonder (NYC)     327
# John             294
# Alex             279

# %%
#47

# neighbourhood_group의 값에 따른 neighbourhood컬럼 값의 갯수를 구하여라

# Ans = df.groupby(['neighbourhood_group', 'neighbourhood'], as_index=False).size()
# Ans.head()

Ans = df[['neighbourhood_group','neighbourhood']].groupby(['neighbourhood_group','neighbourhood'], as_index = False).size()
Ans.head()
# Out:
#   neighbourhood_group neighbourhood  size
# 0               Bronx      Allerton    42
# 1               Bronx    Baychester     7
# 2               Bronx       Belmont    24
# 3               Bronx     Bronxdale    19
# 4               Bronx   Castle Hill     9

# %%
#48

# neighbourhood_group의 값에 따른 neighbourhood컬럼 값 중 neighbourhood_group그룹의 최댓값들을  출력하라

# 내가 작성한 오답
# Ans = df[['neighbourhood_group','neighbourhood']].groupby(['neighbourhood_group','neighbourhood'], as_index = False).size().max()
# Ans.head()

# 블로그의 정답
# Ans = df.groupby(['neighbourhood_group','neighbourhood'], as_index=False).size().groupby(['neighbourhood_group'],as_index=False).max()
# Ans


# 인강의 코드(그룹별로 정렬한 뒤 중복된 neighbourhood_group을 날려버리고 첫번째행만 남김)
Ans = df[['neighbourhood_group','neighbourhood']].groupby(['neighbourhood_group','neighbourhood'], as_index=False).size()
#pd.set_option('display.max_rows', 250)
Ans.sort_values(['neighbourhood_group','size'],ascending=[True,False]).drop_duplicates('neighbourhood_group', keep='first')
# Out:
#     neighbourhood_group neighbourhood  size
# 18                Bronx   Kingsbridge    70
# 93             Brooklyn  Williamsburg  3920
# 105           Manhattan        Harlem  2658
# 128              Queens       Astoria   900
# 212       Staten Island    St. George    48

# %%
#49
# neighbourhood_group값에 따른 price값의 평균, 분산, 최대, 최소 값을 구하여라

# 나의 오답
# Ans = df[['neighbourhood_group','price']].groupby(['neighbourhood_group']).mean()
# Ans

Ans = df[['neighbourhood_group','price']].groupby(['neighbourhood_group']).agg(['mean','var','max','min'])
Ans
# Out:
#                           price
#                            mean           var    max min
# neighbourhood_group
# Bronx                 87.496792  11386.885081   2500   0
# Brooklyn             124.383207  34921.719135  10000   0
# Manhattan            196.875814  84904.159185  10000   0
# Queens                99.517649  27923.130227  10000  10
# Staten Island        114.812332  77073.088342   5000  13

# %%
#50

Ans = df[['neighbourhood_group','reviews_per_month']].groupby('neighbourhood_group').agg(['mean','var','max','min'])
Ans
# Out:
#                     reviews_per_month
#                                  mean       var    max   min
# neighbourhood_group
# Bronx                        1.837831  2.799878  10.34  0.02
# Brooklyn                     1.283212  2.299040  14.00  0.01
# Manhattan                    1.272131  2.651206  58.50  0.01
# Queens                       1.941200  4.897848  20.94  0.01
# Staten Island                1.872580  2.840895  10.12  0.02

# %%
#51

# 나의 오답
# Ans = df[['neighbourhood','neighbourhood_group']].groupby(['neighbourhood','neighbourhood_group']).mean('price')
# Ans

Ans = df.groupby(['neighbourhood','neighbourhood_group']).price.mean()
Ans.head()
# Out:
# neighbourhood  neighbourhood_group
# Allerton       Bronx                   87.595238
# Arden Heights  Staten Island           67.250000
# Arrochar       Staten Island          115.000000
# Arverne        Queens                 171.779221
# Astoria        Queens                 117.187778
# Name: price, dtype: float64

# %%
#52
# neighbourhood와 neighbourhood_group에 따른 price의 평균을 계층적 indexing 없이 구하라

# Ans = df.groupby(['neighbourhood','neighbourhood_group'], as_index = False).price.mean()
# Ans

# or

Ans = df.groupby(['neighbourhood','neighbourhood_group']).price.mean().unstack()
Ans.head()
# Out:
# neighbourhood_group      Bronx  Brooklyn  Manhattan      Queens  Staten Island
# neighbourhood
# Allerton             87.595238       NaN        NaN         NaN            NaN
# Arden Heights              NaN       NaN        NaN         NaN          67.25
# Arrochar                   NaN       NaN        NaN         NaN         115.00
# Arverne                    NaN       NaN        NaN  171.779221            NaN
# Astoria                    NaN       NaN        NaN  117.187778            NaN

# %%
#53

Ans = df.groupby(['neighbourhood','neighbourhood_group']).price.mean().unstack().fillna(-999)
Ans.head()
# Out:
# neighbourhood_group       Bronx  Brooklyn  Manhattan      Queens  \
# neighbourhood
# Allerton              87.595238    -999.0     -999.0 -999.000000
# Arden Heights       -999.000000    -999.0     -999.0 -999.000000
# Arrochar            -999.000000    -999.0     -999.0 -999.000000
# Arverne             -999.000000    -999.0     -999.0  171.779221
# Astoria             -999.000000    -999.0     -999.0  117.187778
#
# neighbourhood_group  Staten Island
# neighbourhood
# Allerton                   -999.00
# Arden Heights                67.25
# Arrochar                    115.00
# Arverne                    -999.00
# Astoria                    -999.00

# %%
#54

Ans = df[df.neighbourhood_group == 'Queens'].groupby(['neighbourhood']).price.agg(['mean','var','max','min'])
Ans.head()
# Out:
#                      mean            var    max  min
# neighbourhood
# Arverne        171.779221   37383.411141   1500   35
# Astoria        117.187778  122428.811196  10000   25
# Bay Terrace    142.000000    6816.400000    258   32
# Bayside        157.948718  166106.470985   2600   30
# Bayswater       87.470588    2330.889706    230   45

# %%
#55
# 데이터 중 neighbourhood_group값에 따른 room_type컬럼의 숫자를 구하고 neighbourhood_group값을 기준으로 각 값의 비율을 구하라
# 이해가 안됨

Ans = df[['neighbourhood_group','room_type']].groupby(['neighbourhood_group','room_type']).size().unstack()
Ans.loc[:,:] = (Ans.values /Ans.sum(axis=1).values.reshape(-1,1))
Ans
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                       0.347388      0.597617     0.054995
# Brooklyn                    0.475478      0.503979     0.020543
# Manhattan                   0.609344      0.368496     0.022160
# Queens                      0.369926      0.595129     0.034945
# Staten Island               0.471850      0.504021     0.024129
