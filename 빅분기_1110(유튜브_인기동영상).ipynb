# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/bigdataanalysis_practice/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0_1110(%EC%9C%A0%ED%8A%9C%EB%B8%8C_%EC%9D%B8%EA%B8%B0%EB%8F%99%EC%98%81%EC%83%81).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
# 인기동영상 제작횟수가 많은 채널 상위 10개명을 출력하라 (날짜기준, 중복포함)

list(df.loc[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.unique())
# Out:
# ['장삐쭈',
#  '총몇명',
#  '파뿌리',
#  '짤툰',
#  '런닝맨 - 스브스 공식 채널',
#  '엠뚜루마뚜루 : MBC 공식 종합 채널',
#  'SPOTV',
#  '채널 십오야',
#  '이과장',
#  'BANGTANTV']

# %%
# 논란으로 인기동영상이 된 케이스를 확인하고 싶다. dislikes수가 like 수보다 높은 동영상을 제작한 채널을 모두 출력하라

list(df.loc[df.likes < df.dislikes].channelTitle.unique())
# Out:
# ['핫도그TV',
#  'ASMR 애정TV',
#  '하얀트리HayanTree',
#  '양팡 YangPang',
#  '철구형 (CHULTUBE)',
#  '왜냐맨하우스',
#  '(MUTUBE)와꾸대장봉준',
#  '오메킴TV',
#  '육지담',
#  'MapleStory_KR',
#  'ROAD FIGHTING CHAMPIONSHIP',
#  '사나이 김기훈',
#  '나혼자산다 STUDIO',
#  'Gen.G esports']

# %%
# 채널명을 바꾼 케이스가 있는지 확인하고 싶다. channelId의 경우 고유값이므로 이를 통해 채널명을 한번이라도 바꾼 채널의 갯수를 구하여라

change = df[['channelTitle','channelId']].drop_duplicates().channelId.value_counts()
target = change[change>1]
print(len(target))
# Out:
# 71

# %%
# 일요일에 인기있었던 영상들중 가장많은 영상 종류(categoryId)는 무엇인가?

df['trending_date2'] = pd.to_datetime(df['trending_date2'])
Ans = df.loc[df['trending_date2'].dt.day_name()=='Sunday'].categoryId.value_counts().index[0]
Ans
# Out:
# 24

# %%
# 각 요일별 인기 영상들의 categoryId는 각각 몇개씩인지 하나의 데이터 프레임으로 표현하라

group = df.groupby([df['trending_date2'].dt.day_name(),'categoryId'],as_index=False).size()
group.pivot_table(index='categoryId', columns='trending_date2')
# Out:
#                   size
# trending_date2  Friday  Monday Saturday  Sunday Thursday Tuesday Wednesday
# categoryId
# 1                243.0   263.0    255.0   274.0    246.0   257.0     234.0
# 2                120.0   105.0    119.0    99.0    128.0   119.0     129.0
# 10               833.0   837.0    776.0   830.0    890.0   894.0     917.0
# 15               187.0   215.0    198.0   217.0    207.0   208.0     207.0
# 17               633.0   668.0    592.0   636.0    682.0   708.0     706.0
# 19                90.0    92.0     87.0    91.0     92.0    89.0      85.0
# 20               283.0   298.0    296.0   289.0    282.0   285.0     291.0
# 22              1288.0  1373.0   1289.0  1337.0   1341.0  1375.0    1333.0
# 23               568.0   594.0    570.0   556.0    560.0   569.0     566.0
# 24              2976.0  3148.0   3066.0  3096.0   2954.0  3084.0    3090.0
# 25               444.0   453.0    422.0   437.0    470.0   452.0     468.0
# ...

# %%
# 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다. viewcount대비 댓글수가 가장 높은  영상을 확인하라 (view_count값이 0인 경우는 제외한다)

zero = df[df['view_count'] != 0]

zero['ratio'] = (zero['comment_count']/zero['view_count']).dropna()

ans = zero.sort_values(by='ratio', ascending = False).iloc[0].title

print(ans)
# Out:
# 60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)
# <ipython-input-29-85d5e0bc206f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zero['ratio'] = (zero['comment_count']/zero['view_count']).dropna()

# %%
# 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다.viewcount대비 댓글수가 가장 낮은 영상을 확인하라 (view_counts, ratio값이 0인경우는 제외한다.)

zero = df[df['view_count'] != 0]

zero['ratio'] = (zero['comment_count']/zero['view_count']).dropna()

t = zero[zero['ratio'] != 0]

ans = t.sort_values(by='ratio', ascending = False).iloc[-1].title

print(ans)
# Out:
# Join the BTS #PermissiontoDance Challenge only on YouTube #Shorts
# <ipython-input-30-22a237c86884>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zero['ratio'] = (zero['comment_count']/zero['view_count']).dropna()

# %%
# like 대비 dislike의 수가 가장 적은 영상은 무엇인가? (like, dislike 값이 0인경우는 제외한다)

t = df[(df['likes'] != 0) & (df['dislikes'] != 0)]

t['ratio'] = (t['dislikes'] / t['likes']).dropna()

ans = t.sort_values(by='ratio', ascending=True).iloc[0].title

print(ans)
# Out:
# [줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가득한 NCT 127 도영&정우의 줌터뷰
# <ipython-input-41-d5b545141577>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['ratio'] = (t['dislikes'] / t['likes']).dropna()

# %%
# 가장많은 트렌드 영상을 제작한 채널의 이름은 무엇인가? (날짜기준, 중복포함)

# df.groupby(['trending_date2','channelTitle']).value_counts().sort_values(ascending=False)

ans = df.loc[df.channelId == df.channelId.value_counts().index[0]].channelTitle.unique()[0]
print(ans)
# Out:
# 짤툰

# %%
# 20회(20일)이상 인기동영상 리스트에 포함된 동영상의 숫자는?

(df[['title', 'channelId']].value_counts()>=20).sum()
# Out:
# 40
