# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/bigdataanalysis_practice/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0_%EC%9E%91%EC%97%851%EC%9C%A0%ED%98%95(%EC%A0%84%EC%84%B8%EA%B3%84_%ED%96%89%EB%B3%B5%EB%8F%84_%EC%A7%80%ED%91%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/happy2/happiness.csv',encoding='utf-8')
df.head()
# Out:
#    행복랭킹          나라명     점수  상대GDP  사회적지원  행복기대치  선택의 자유도    관대함  부패에 대한인식  \
# 0     1      Finland  7.769  1.340  1.587  0.986    0.596  0.153     0.393
# 1     2      Denmark  7.600  1.383  1.573  0.996    0.592  0.252     0.410
# 2     3       Norway  7.554  1.488  1.582  1.028    0.603  0.271     0.341
# 3     4      Iceland  7.494  1.380  1.624  1.026    0.591  0.354     0.118
# 4     5  Netherlands  7.488  1.396  1.522  0.999    0.557  0.322     0.298
#
#      년도
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
#41
# 각 년도의 행복랭킹 10위를 차지한 나라의 행복점수 평균

Ans = df[(df.행복랭킹) == 10].점수.mean()
print(Ans)
# Out:
# 7.259

# %%
#42
# 각년도의 행복랭킹 50위이내의 나라들의 각각의 행복점수 평균을 데이터프레임으로 표시

Ans = df[(df.행복랭킹) <= 50][['년도','점수']].groupby('년도').mean()
print(Ans)
# Out:
#            점수
# 년도
# 2018  6.64678
# 2019  6.67002

# %%
#43
# 2018년도 데이터들만 추출하여 행복점수와 부패에 대한 인식에 대한 상관계수

Ans = df[(df.년도) == 2018][['점수','부패에 대한인식']].corr().iloc[0,1]
print(Ans)
# Out:
# 0.40529152271510027

# %%
#44
# 2018년도와 2019년도의 행복랭킹이 변화하지 않은 나라명의 수를 구하여라

result = len(df[['행복랭킹','나라명']]) - len(df[['행복랭킹','나라명']].drop_duplicates())
print(result)
# Out:
# 15

# %%
#45
# 2019년도 데이터들만 추출하여 각변수간 상관계수를 구하고 내림차순으로 정렬한 후 상위 5개를 데이터 프레임으로  출력, 컬럼명은 v1,v2,corr으로 표시

# 숫자 열만 선택
numeric_columns = df.select_dtypes(include='number')
gu = numeric_columns[numeric_columns['년도'] == 2019].corr().unstack().to_frame().reset_index().dropna()


result = gu[gu[0] != 1].sort_values(0, ascending = False).drop_duplicates(0)
Ans = result.head(5).reset_index(drop = True)
Ans.columns = ['v1','v2','corr']
display(Ans)
# Out:
#       v1     v2      corr
# 0  행복기대치  상대GDP  0.835462
# 1  상대GDP     점수  0.793883
# 2  행복기대치     점수  0.779883
# 3  사회적지원     점수  0.777058
# 4  사회적지원  상대GDP  0.754906

# %%
#46
# 각 년도별 하위 행복점수의 하위 5개 국가의 평균 행복점수

# 나의 오답
# Ans = df[(df.점수)].groupby('년도').sort_values('점수', ascending = True).head(5)
# print(Ans)

# 이게 맞나..?
result = df.groupby('년도')['점수'].mean().tail(5)
print(result)
# Out:
# 년도
# 2018    5.375917
# 2019    5.407096
# Name: 점수, dtype: float64

# %%
#47
# 2019년 데이터를 추출하고 해당데이터의 상대 GDP 평균 이상의 나라들과 평균 이하의 나라들의 행복점수 평균을 각각 구하고 그 차이값을  출력하라

gu = df[df.년도 == 2019]
isang = gu[gu['상대GDP'] >= gu['상대GDP'].mean()].점수.mean()
iha = gu[gu['상대GDP'] <= gu['상대GDP'].mean()].점수.mean()
Ans = isang - iha
print(Ans)
# Out:
# 1.390483957219251

# %%
#48
# 각년도의 부패에 대한인식을 내림차순 정렬했을때 상위 20개 국가의 부패에 대한인식의 평균

Ans = df.sort_values(['년도','부패에 대한인식'], ascending= [False,False]).groupby('년도').head(20).groupby(['년도'])['부패에 대한인식'].mean()
print(Ans)
# Out:
# 년도
# 2018    0.3267
# 2019    0.3201
# Name: 부패에 대한인식, dtype: float64

# %%
#49
# 2018년도 행복랭킹 50위 이내에 포함됐다가 2019년 50위 밖으로 밀려난 국가의 숫자

away = set(df[(df.년도 == 2018) & (df.행복랭킹 <= 50)].나라명) - set(df[(df.년도 == 2019) & (df.행복랭킹 <= 50)].나라명)
Ans = len(away)
print(Ans)
# Out:
# 4

# %%
#50
# 2018년,2019년 모두 기록이 있는 나라들 중 년도별 행복점수가 가장 증가한 나라와 그 증가 수치는?

cnt = df.나라명.value_counts()
target = cnt[cnt >= 2].index

df2 = df.copy()
multi = df2[df2.나라명.isin(target).reset_index(drop = True)]
multi.loc[multi['년도'] == 2018, '점수'] =multi[multi.년도 == 2018]['점수'].values * (-1)
result = multi.groupby('나라명').sum()['점수'].sort_values().to_frame().iloc[-1]
print(result)
# Out:
# 점수    0.87
# Name: Burundi, dtype: float64
