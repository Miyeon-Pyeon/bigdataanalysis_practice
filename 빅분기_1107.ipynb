# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/bigdataanalysis_practice/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0_1107.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/timeTest.csv')

df.head()
# Out:
#      Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Yr_Mo_Dy  6574 non-null   object
#  1   RPT       6568 non-null   float64
#  2   VAL       6571 non-null   float64
#  3   ROS       6572 non-null   float64
#  4   KIL       6569 non-null   float64
#  5   SHA       6572 non-null   float64
#  6   BIR       6574 non-null   float64
#  7   DUB       6571 non-null   float64
#  8   CLA       6572 non-null   float64
#  9   MUL       6571 non-null   float64
#  10  CLO       6573 non-null   float64
#  11  BEL       6574 non-null   float64
#  12  MAL       6570 non-null   float64
# dtypes: float64(12), object(1)
# memory usage: 667.8+ KB

# %%
# Yr_Mo_Dy을 판다스에서 인식할 수 있는 datetime64타입으로 변경하라

df.Yr_Mo_Dy = pd.to_datetime(df.Yr_Mo_Dy)
df.Yr_Mo_Dy.head()
# Out:
# 0   2061-01-01
# 1   2061-01-02
# 2   2061-01-03
# 3   2061-01-04
# 4   2061-01-05
# Name: Yr_Mo_Dy, dtype: datetime64[ns]

# %%
# Yr_Mo_Dy에 존재하는 년도의 유일값을 모두 출력하라

df.Yr_Mo_Dy.dt.year.unique()
# Out:
# array([2061, 2062, 2063, 2064, 2065, 2066, 2067, 2068, 2069, 2070, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978], dtype=int32)

# %%
# Yr_Mo_Dy에 년도가 2061년 이상의 경우에는 모두 잘못된 데이터이다. 해당경우의 값은 100을 빼서 새롭게 날짜를 Yr_Mo_Dy 컬럼에 정의하라

def fix_century(x):
  import datetime

  year = x.year - 100 if x.year >= 2061 else x.year
  return pd.to_datetime(datetime.date(year, x.month, x.day))

df['Yr_Mo_Dy'] = df['Yr_Mo_Dy'].apply(fix_century)

df.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
# 년도별 각컬럼의 평균값을 구하여라

df.groupby(df.Yr_Mo_Dy.dt.year).mean()
# Out:
#                     Yr_Mo_Dy        RPT        VAL        ROS       KIL  \
# Yr_Mo_Dy
# 1961     1961-07-02 00:00:00  12.299583  10.351796  11.362369  6.958227
# 1962     1962-07-02 00:00:00  12.246923  10.110438  11.732712  6.960440
# 1963     1963-07-02 00:00:00  12.813452  10.836986  12.541151  7.330055
# 1964     1964-07-01 12:00:00  12.363661  10.920164  12.104372  6.787787
# 1965     1965-07-02 00:00:00  12.451370  11.075534  11.848767  6.858466
# 1966     1966-07-02 00:00:00  13.461973  11.557205  12.020630  7.345726
# 1967     1967-07-02 00:00:00  12.737151  10.990986  11.739397  7.143425
# 1968     1968-07-01 12:00:00  11.835628  10.468197  11.409754  6.477678
# 1969     1969-07-02 00:00:00  11.166356   9.723699  10.902000  5.767973
# 1970     1970-07-02 00:00:00  12.600329  10.726932  11.730247  6.217178
# 1971     1971-07-02 00:00:00  11.273123   9.095178  11.088329  5.241507
# 1972     1972-07-01 12:00:00  12.463962  10.561311  12.058333  5.929699
# ...

# %%
# weekday컬럼을 만들고 요일별로 매핑하라 ( 월요일: 0 ~ 일요일 :6)

# def weekend(x):
#   if           > 이렇게 하는거 아님

df['weekday'] = df.Yr_Mo_Dy.dt.weekday
df['weekday'].to_frame().head()
# Out:
#    weekday
# 0        6
# 1        0
# 2        1
# 3        2
# 4        3

# %%
# weekday컬럼을 기준으로 주말이면 1 평일이면 0의 값을 가지는 WeekCheck 컬럼을 만들어라

# df['weekday'] = df.Yr_Mo_Dy.dt.weekday

# def weekend(x):
#   if 0 <= x.WeekCheck <= 4:
#     return 0
#   else:
#     return 1

# df['WeekCheck'] = df['WeekCheck'].apply(weekend)  > 오답

df['WeekCheck'] = df['weekday'].map(lambda x : 1 if x in [5,6] else 0)

df['WeekCheck'].to_frame().head()
# Out:
#    WeekCheck
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# 년도, 일자 상관없이 모든 컬럼의 각 달의 평균을 구하여라

df.groupby(df.Yr_Mo_Dy.dt.month).mean()
# Out:
#                               Yr_Mo_Dy        RPT        VAL        ROS  \
# Yr_Mo_Dy
# 1        1969-07-17 06:40:00.000000000  14.847325  12.914560  13.299624
# 2        1969-08-17 07:50:33.070866142  13.710906  12.111122  12.879132
# 3        1969-09-14 12:00:00.000000000  13.158687  11.505842  12.648118
# 4        1969-10-15 00:00:00.000000000  12.555648  10.429759  12.204815
# 5        1969-11-14 12:00:00.000000000  11.724032  10.145619  11.550394
# 6        1969-12-15 00:00:00.000000000  10.451317   8.949704  10.361315
# 7        1970-01-14 12:00:00.000000000   9.992007   8.357778   9.349642
# 8        1970-02-14 12:00:00.000000000  10.213411   8.415143   9.993441
# 9        1970-03-17 00:00:00.000000000  11.458519   9.981002  10.756883
# 10       1970-04-16 12:00:00.000000000  12.660610  11.010681  11.453943
# 11       1970-05-17 00:00:00.000000000  13.200722  11.639500  12.293407
# 12       1970-06-16 12:00:00.000000000  14.446398  12.353602  13.212276
#
# ...

# %%
# 모든 결측치는 컬럼기준 직전의 값으로 대체하고 첫번째 행에 결측치가 있을경우 뒤에있는 값으로 대체하라

df = df.fillna(method='ffill').fillna(method='bfill').head()
# Out:
# <ipython-input-17-aaa74987fd2a>:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').fillna(method='bfill').head()

# %%
df.isna().sum()
# Out:
# Yr_Mo_Dy     0
# RPT          0
# VAL          0
# ROS          0
# KIL          0
# SHA          0
# BIR          0
# DUB          0
# CLA          0
# MUL          0
# CLO          0
# BEL          0
# MAL          0
# weekday      0
# WeekCheck    0
# dtype: int64

# %%
# df.groupby(df.Yr_Mo_Dy).mean()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Yr_Mo_Dy
# 1961-01-01  15.04  14.96  13.17   9.29  12.62  9.87  13.67  10.25  10.83
# 1961-01-02  14.71  14.96  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25  10.04   8.50
# 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL  weekday  WeekCheck
# Yr_Mo_Dy
# 1961-01-01  12.58  18.50  15.04      6.0        1.0
# 1961-01-02   9.67  17.54  13.83      0.0        0.0
# 1961-01-03   7.67  12.75  12.71      1.0        0.0
# 1961-01-04   5.88   5.46  10.88      2.0        0.0
# 1961-01-05  10.34  12.92  11.83      3.0        0.0

# %%
# 년도 - 월을 기준으로 모든 컬럼의 평균값을 구하여라

df.groupby(df.Yr_Mo_Dy.dt.to_period('M')).mean()
# Out:
#            Yr_Mo_Dy     RPT     VAL   ROS    KIL     SHA   BIR     DUB    CLA  \
# Yr_Mo_Dy
# 1961-01  1961-01-03  14.432  13.336  11.9  7.334  10.332  6.96  11.394  7.732
#
#             MUL    CLO     BEL     MAL  weekday  WeekCheck
# Yr_Mo_Dy
# 1961-01   9.174  9.228  13.434  12.858      2.4        0.2

# %%
# RPT 컬럼의 값을 일자별 기준으로 1차차분하라

df['RPT'].diff()
# Out:
# 0     NaN
# 1   -0.33
# 2    3.79
# 3   -7.92
# 4    2.75
# Name: RPT, dtype: float64

# %%
# RPT와 VAL의 컬럼을 일주일 간격으로 각각 이동평균한값을 구하여라

df[['RPT','VAL']].rolling(7).mean()
# Out:
#    RPT  VAL
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN

# %%
df =pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/seoul_pm.csv')
df.head()
# Out:
#        (년-월-일:시) PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소  \
# 0  2021-05-15:15     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023
# 1  2021-05-15:14     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019
# 2  2021-05-15:13     보통  34.0      보통   24.0   보통  0.035      좋음  0.017
# 3  2021-05-15:12     보통  41.0      보통   27.0   보통  0.037      좋음  0.020
# 4  2021-05-15:11     보통  51.0      보통   34.0   보통  0.033      좋음  0.023
#
#   일산화탄소등급  일산화탄소 아황산가스등급  아황산가스
# 0      좋음    0.4      좋음  0.003
# 1      좋음    0.3      좋음  0.003
# 2      좋음    0.4      좋음  0.004
# 3      좋음    0.4      좋음  0.004
# 4      좋음    0.4      좋음  0.005

# %%
# 년-월-일:시 컬럼을 pandas에서 인식할 수 있는 datetime 형태로 변경하라. 서울시의 제공데이터의 경우 0시가 24시로 표현된다

def change_date(x):
  import datetime
  hour = x.split(':')[1]
  date = x.split(':')[0]

  if hour == '24':
    hour = '00:00:00'

    FinalDate = pd.to_datetime(date + " "+hour) + datetime.timedelta(days=1)

  else:
    hour = hour + ':00:00'
    FinalDate = pd.to_datetime(date + " "+ hour)

  return FinalDate

df['(년-월-일:시)'] = df['(년-월-일:시)'].apply(change_date)

df.head()
# Out:
#             (년-월-일:시) PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소  \
# 0 2021-05-15 15:00:00     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023
# 1 2021-05-15 14:00:00     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019
# 2 2021-05-15 13:00:00     보통  34.0      보통   24.0   보통  0.035      좋음  0.017
# 3 2021-05-15 12:00:00     보통  41.0      보통   27.0   보통  0.037      좋음  0.020
# 4 2021-05-15 11:00:00     보통  51.0      보통   34.0   보통  0.033      좋음  0.023
#
#   일산화탄소등급  일산화탄소 아황산가스등급  아황산가스
# 0      좋음    0.4      좋음  0.003
# 1      좋음    0.3      좋음  0.003
# 2      좋음    0.4      좋음  0.004
# 3      좋음    0.4      좋음  0.004
# 4      좋음    0.4      좋음  0.005

# %%
# 일자별 영어요일 이름을 dayName 컬럼에 저장하라

df['dayName'] = df['(년-월-일:시)'].dt.day_name()
df['dayName'].head()
# Out:
# 0    Saturday
# 1    Saturday
# 2    Saturday
# 3    Saturday
# 4    Saturday
# Name: dayName, dtype: object

# %%
# 일자별 각 PM10등급의 빈도수를 파악하라

df.groupby(['dayName','PM10등급'],as_index=False).size().head()
# Out:
#   dayName PM10등급  size
# 0  Friday     나쁨    31
# 1  Friday   매우나쁨    17
# 2  Friday     보통   120
# 3  Friday     좋음    21
# 4  Monday     나쁨     1

# %%
# Ans1 = df.groupby(['dayName','PM10등급'],as_index=False).size()
# Ans2 = Ans1.pivot(index='dayName',columns='PM10등급',values='size').fillna(0)
# Ans2.head()
# Out:
# PM10등급      나쁨  매우나쁨     보통    좋음
# dayName
# Friday    31.0  17.0  120.0  21.0
# Monday     1.0  21.0   83.0  63.0
# Saturday  31.0  27.0   71.0  54.0
# Sunday     2.0   1.0   67.0  98.0
# Thursday  41.0   0.0  144.0   5.0

# %%
# 시간이 연속적으로 존재하며 결측치가 없는지 확인하라

check = len(df['(년-월-일:시)'].diff().unique())
if check == 2:
  Ans = True
else:
  Ans = False

Ans
# Out:
# True

# %%
# 오전 10시와 오후 10시(22시)의 PM10의 평균값을 각각 구하여라

df.groupby(df['(년-월-일:시)'].dt.hour)['PM10'].mean().iloc[[10,22]]
# Out:
# (년-월-일:시)
# 10    70.384615
# 22    69.941176
# Name: PM10, dtype: float64

# %%
# 날짜 컬럼을 index로 만들어라

df.set_index('(년-월-일:시)', inplace=True, drop=True)

df.head()
# Out:
#               PM10등급  PM10 PM2.5등급  PM2.5 오존등급     오존 이산화질소등급  이산화질소 일산화탄소등급  \
# (년-월-일:시)
# 2021-05-15:15     보통  47.0      보통   19.0   좋음  0.017      좋음  0.023      좋음
# 2021-05-15:14     보통  43.0      보통   20.0   좋음  0.024      좋음  0.019      좋음
# 2021-05-15:13     보통  34.0      보통   24.0   보통  0.035      좋음  0.017      좋음
# 2021-05-15:12     보통  41.0      보통   27.0   보통  0.037      좋음  0.020      좋음
# 2021-05-15:11     보통  51.0      보통   34.0   보통  0.033      좋음  0.023      좋음
#
#                일산화탄소 아황산가스등급  아황산가스
# (년-월-일:시)
# 2021-05-15:15    0.4      좋음  0.003
# 2021-05-15:14    0.3      좋음  0.003
# 2021-05-15:13    0.4      좋음  0.004
# 2021-05-15:12    0.4      좋음  0.004
# 2021-05-15:11    0.4      좋음  0.005

# %%
# 데이터를 주단위로 뽑아서 최소,최대 평균, 표준표차를 구하여라

# df['(년-월-일:시)'] = pd.to_datetime(df['(년-월-일:시)'], errors='coerce')

# df = df.dropna(subset=['(년-월-일:시)'])

# df = df.set_index('(년-월-일:시)')

Ans = df.resample('W').agg(['min','max','mean','std'])

Ans

# >> 왜 결과가 안나오는거지? 인덱스로 지정도 다 했는데..
# Out:
# <ipython-input-71-57a2b7da389a>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['(년-월-일:시)'] = pd.to_datetime(df['(년-월-일:시)'], errors='coerce')
# Empty DataFrame
# ...
