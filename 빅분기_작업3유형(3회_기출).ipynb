# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/bigdataanalysis_practice/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0_%EC%9E%91%EC%97%853%EC%9C%A0%ED%98%95(3%ED%9A%8C_%EA%B8%B0%EC%B6%9C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 투약 후 체중에서 투약 전 체중을 뺏을 때 값은 일반 적으로 세가지 등급으로 나눈다.
# -3이하 : A등급, -3초과 0이하 : B등급, 0 초과 : C등급. 약 실험에서 A,B,C 그룹간의 인원 수 비율은 2:1:1로 알려져 있다.
# 위 데이터 표본은 각 범주의 비율에 적합한지 카이제곱 검정하려한다.

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e3_p3_1.csv')
df.head()
# Out:
#        ID     투약전     투약후
# 0  user_1  55.137  56.106
# 1  user_2  66.584  60.409
# 2  user_3  52.259  50.639
# 3  user_4  77.081  69.164
# 4  user_5  62.677  57.622

# %%
# 1
# A등급에 해당하는 유저는 몇명인지 확인하라

df['grade'] = df['투약후'] - df['투약전']

def filter(x):
  if x <= -3:
    return 'A'
  elif x <= 0:
    return 'B'
  else:
    return 'C'

df['groupby'] = df['grade'].apply(filter)
result = df['groupby'].value_counts().sort_index()['A']
print(result)
# Out:
# 121

# %%
# 2
# 카이제곱검정 통계량을 반올림하여 소숫점 이하 3째자리까지 구하여라

target = df['groupby'].value_counts().sort_index().to_frame()

from scipy.stats import chisquare

expected = [target.sum() * 0.5, target.sum() * 0.25, target.sum() * 0.25]

# 카이제곱 검정 수행
s, p = chisquare(target, expected)

print(round(s,3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-fbc60aed7726> in <cell line: 13>()
#      11 s, p = chisquare(target, expected)
#      12
# ---> 13 print(round(s,3))
#
# TypeError: type numpy.ndarray doesn't define __round__ method

# %%
# 3
# 카이제곱 검정 p값을 반올림하여 소숫점 이하 3자리까지 구하고, 유의수준 0.05하에서 귀무가설과 대립가설중 유의한 가설을 하나를 선택하시오(귀무/대립)

print(round(p,3))

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e3_p3_2_.csv')
df.head()
# Out:
#      rpm group
# 0  163.6     A
# 1  246.9     A
# 2  234.9     A
# 3  156.9     A
# 4  226.6     A

# %%
# 4
# A,B 공장 각각 정규성을 가지는지 샤피로 검정을 통해 확인하라. (각 공장의 pvalue 출력할 것)

from scipy.stats import shapiro

a = df[df['group'] == 'A'].rpm
b = df[df['group'] == 'B'].rpm
print(shapiro(a))
print(shapiro(b))
# Out:
# ShapiroResult(statistic=0.9863898158073425, pvalue=0.397915244102478)
# ShapiroResult(statistic=0.9943947196006775, pvalue=0.9562925100326538)

# %%
# 5
# A,B 공장 생산 제품의 rpm은 각각 정규성을 가지는지 샤피로 검정을 통해 확인하라. (각 공장의 pvalue 출력할 것)

from scipy.stats import levene

s, p = levene(a, b)

print(round(p, 3))
# Out:
# 0.904

# %%
# 6
# 대응 표본 t 검정을 통해 B공장 제품들의 rpm이 A 공장 제품의 rpm보다 크다고 말할 수 있는지 검정하라.
# pvalue를 소숫점 이하 3자리까지 출력하고 귀무가설, 대립가설 중 하나를  출력하라

from scipy.stats import ttest_rel

s, p = ttest_rel(b,a,alternative='greater')
print(round(p,3))

# 0.05보다 작으므로 기각 따라서 대립가설이 유의함
# Out:
# 0.009
