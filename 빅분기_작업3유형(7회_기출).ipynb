# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/bigdataanalysis_practice/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0_%EC%9E%91%EC%97%853%EC%9C%A0%ED%98%95(7%ED%9A%8C_%EA%B8%B0%EC%B6%9C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p3_1.csv')
df.head()
# Out:
#       Target        v1        v2        v3        v4        v5        v6  \
# 0  21.650072  0.496714 -0.138264  0.647689  1.523030 -0.234153 -0.234137
# 1 -19.469855 -0.225776  0.067528 -1.424748 -0.544383  0.110923 -1.150994
# 2 -24.475600 -0.115648 -0.301104 -1.478522 -0.719844 -0.460639  1.057122
# 3  13.476831 -1.196207  0.812526  1.356240 -0.072010  1.003533  0.361636
# 4   3.505322 -0.808494 -0.501757  0.915402  0.328751 -0.529760  0.513267
#
#          v7        v8        v9  ...       v12       v13       v14       v15  \
# 0  1.579213  0.767435 -0.469474  ... -0.465730  0.241962 -1.913280 -1.724918
# 1  0.375698 -0.600639 -0.291694  ... -0.013497 -1.057711  0.822545 -1.220844
# 2  0.343618 -1.763040  0.324084  ...  0.611676  1.031000  0.931280 -0.839218
# 3 -0.645120  0.361396  1.538037  ... -2.619745  0.821903  0.087047 -0.299007
# 4  0.097078  0.968645 -0.702053  ... -1.463515  0.296120  0.261055  0.005113
#
#         v16       v17       v18       v19       v20       v21
# 0 -0.562288 -1.012831  0.314247 -0.908024 -1.412304  1.465649
# 1  0.208864 -1.959670 -1.328186  0.196861  0.738467  0.171368
# 2 -0.309212  0.331263  0.975545 -0.479174 -0.185659 -1.106335
# 3  0.091761 -1.987569 -0.219672  0.357113  1.477894 -0.518270
# 4 -0.234587 -1.415371 -0.420645 -0.342715 -0.802277 -0.161286
#
# [5 rows x 22 columns]

# %%
# 1
# 선형관계 가장 큰 변수 찾아 상관계수를 구하여라

Ans = df.corr()['Target'].sort_values().values[-2]
print(Ans)
# Out:
# 0.6270251925517436

# %%
# 2
# Target 변수를 종속변수로 하여 다중선형회귀모델링을 진행했을 때 v2 컬럼의 회귀 계수는?

import numpy as np
import pandas as pd
import statsmodels.api as sm

X = df.drop('Target', axis = 1)
X = sm.add_constant(X)   # 상수항 추가
y = df['Target']

model = sm.OLS(y,X).fit()
print(model.params['v2'])
# Out:
# 6.440301364843059

# %%
# 3
# 회귀 계수들이 가지는 p값들 중 최대 값은?

Ans = model.pvalues.max()
print(Ans)
# Out:
# 0.9265545986905969

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/krdatacertificate/e7_p3_t.csv')
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  target
# 0    3.0  0.0   6.0       0
# 1    2.0  3.0   3.0       1
# 2    2.0  2.0   7.0       1
# 3    3.0  0.0   3.0       0
# 4    1.0  0.0   3.0       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 297 entries, 0 to 296
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       297 non-null    float64
#  1   sex       297 non-null    float64
#  2   cp        297 non-null    float64
#  3   trestbps  297 non-null    float64
#  4   chol      297 non-null    float64
#  5   fbs       297 non-null    float64
#  6   restecg   297 non-null    float64
#  7   thalach   297 non-null    float64
#  8   exang     297 non-null    float64
#  9   oldpeak   297 non-null    float64
#  10  slope     297 non-null    float64
#  11  ca        297 non-null    float64
#  12  thal      297 non-null    float64
#  13  target    297 non-null    int64
# dtypes: float64(13), int64(1)
# memory usage: 32.6 KB

# %%
# 4
# train 데이터로 target을 종속변수로 로지스틱 회귀를 진행할 때 age 컬럼의 오즈비를 구하여라

import pandas as pd
import numpy as np
import statsmodels.api as sm

train = df.iloc[:200].reset_index(drop=True)    # drop=True는 기존 인덱스를 새로운 열로 추가하지 않게
test = df.iloc[200:].reset_index(drop = True)

X = train.drop('target', axis=1)
y = train['target']

model = sm.Logit(y,X).fit()

odds_ratios = np.exp(model.params['age'])
print(odds_ratios)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.339239
#          Iterations 7
# 0.9562946818277593

# %%
# 5
# train으로 로지스틱 회귀 진행했을 경우 잔차 이탈도 (residual deviance)를 계산하라

model2 = sm.GLM(y,X, family = sm.families.Binomial()).fit()

# 잔차 이탈도 계산
residual_deviance = model2.deviance
print(residual_deviance)
# Out:
# 135.69574778065873

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 target   No. Observations:                  200
# Model:                            GLM   Df Residuals:                      187
# Model Family:                Binomial   Df Model:                           12
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -67.848
# Date:                Sun, 16 Jun 2024   Deviance:                       135.70
# Time:                        07:15:48   Pearson chi2:                     199.
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.5023
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age           -0.0447      0.027     -1.630      0.103      -0.098       0.009
# sex            1.3425      0.628      2.137      0.033       0.111       2.574
# cp             0.6577      0.248      2.653      0.008       0.172       1.144
# trestbps       0.0196      0.012      1.600      0.110      -0.004       0.044
# chol           0.0050      0.004      1.121      0.262      -0.004       0.014
# fbs           -0.8337      0.629     -1.326      0.185      -2.066       0.398
# restecg        0.4399      0.238      1.848      0.065      -0.027       0.906
# thalach       -0.0526      0.012     -4.408      0.000      -0.076      -0.029
# exang          0.5330      0.504      1.057      0.290      -0.455       1.521
# oldpeak        0.2479      0.250      0.991      0.322      -0.243       0.738
# slope          0.1549      0.416      0.372      0.710      -0.661       0.971
# ca             0.9369      0.299      3.137      0.002       0.352       1.522
# thal           0.3427      0.126      2.725      0.006       0.096       0.589
# ==============================================================================
# """

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 target   No. Observations:                  200
# Model:                          Logit   Df Residuals:                      187
# Method:                           MLE   Df Model:                           12
# Date:                Sun, 16 Jun 2024   Pseudo R-squ.:                  0.5070
# Time:                        07:15:55   Log-Likelihood:                -67.848
# converged:                       True   LL-Null:                       -137.63
# Covariance Type:            nonrobust   LLR p-value:                 7.349e-24
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age           -0.0447      0.027     -1.630      0.103      -0.098       0.009
# sex            1.3425      0.628      2.137      0.033       0.111       2.574
# cp             0.6577      0.248      2.653      0.008       0.172       1.144
# trestbps       0.0196      0.012      1.600      0.110      -0.004       0.044
# chol           0.0050      0.004      1.121      0.262      -0.004       0.014
# fbs           -0.8337      0.629     -1.326      0.185      -2.066       0.398
# restecg        0.4399      0.238      1.848      0.065      -0.027       0.906
# thalach       -0.0526      0.012     -4.408      0.000      -0.076      -0.029
# exang          0.5330      0.504      1.057      0.290      -0.455       1.521
# oldpeak        0.2479      0.250      0.991      0.322      -0.243       0.738
# slope          0.1549      0.416      0.372      0.710      -0.661       0.971
# ca             0.9369      0.299      3.137      0.002       0.352       1.522
# thal           0.3427      0.126      2.725      0.006       0.096       0.589
# ==============================================================================
# """

# %%
# 6
# train으로 로지스틱 회귀 진행했을 경우 로짓 우도값을 도출하라

Log_likelihood = model.llf
print(Log_likelihood)
# Out:
# -67.84787389032935

# %%
# 7
# test 데이터의 독립변수로 target 예측 후 오류율을 구하여라

pred = (model.predict(test.drop(columns=['target']))>0.5).astype('int')

from sklearn.metrics import accuracy_score

error_rate = 1 - accuracy_score(test['target'], pred)
print(error_rate)
# Out:
# 0.18556701030927836
