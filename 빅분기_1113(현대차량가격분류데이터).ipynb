# %% [markdown]
# <a href="https://colab.research.google.com/github/Miyeon-Pyeon/bigdataanalysis_practice/blob/master/%EB%B9%85%EB%B6%84%EA%B8%B0_1113(%ED%98%84%EB%8C%80%EC%B0%A8%EB%9F%89%EA%B0%80%EA%B2%A9%EB%B6%84%EB%A5%98%EB%8D%B0%EC%9D%B4%ED%84%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/hyundai/train.csv")
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax(£)   mpg  \
# 0   Tucson  2016  12795       Manual    36263   Diesel      30  61.7
# 1      I10  2012   3995       Manual    22089   Petrol      20  61.4
# 2      I30  2019  24000       Manual      555   Petrol     145  34.0
# 3   Tucson  2017  12995       Manual    32147   Diesel      30  61.7
# 4   Tucson  2018  14991    Semi-Auto    32217   Diesel     150  57.6
#
#    engineSize
# 0         1.7
# 1         1.2
# 2         2.0
# 3         1.7
# 4         1.7

# %%
# 정보(row수)가 가장 많은 상위 3차종의 price값의 각 평균값은?

df.loc[df.model.isin(df.model.value_counts().index[:3])].groupby('model')['price'].mean().to_frame()
# Out:
#                price
# model
# I10      7646.137891
# I30     11651.821759
# Tucson  15805.441373
